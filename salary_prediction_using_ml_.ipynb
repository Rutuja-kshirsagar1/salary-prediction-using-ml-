# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutuja-kshirsagar1/salary-prediction-using-ml-/blob/main/salary_prediction_using_ml_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# salary prediction model

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (40, 2)

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
x=df["Experience Years"]
y=df["Salary"]

# %%
import matplotlib.pyplot as plt


x = df[["Experience Years"]]
y = df["Salary"]

plt.figure(figsize=(6,4))
plt.scatter(x, y, color="blue", marker="o")

plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42)

# %%
X_train.shape , X_test.shape,y_train.shape , y_test.shape
# Out:
# ((32, 1), (8, 1), (32,), (8,))

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)*100
# Out:
# 96.43333811854808

# %%
year=float(input("enter your year of experience:"))
lr.predict([[year]])
# Out:
# enter your year of experience:1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36124.28144865])

# %%
lr.intercept_
# Out:
# np.float64(26716.250176145535)

# %%
lr.coef_
# Out:
# array([9408.03127251])

# %%
x = df[["Experience Years"]]
y = df["Salary"]

plt.figure(figsize=(6,4))
plt.scatter(x, y, color="blue", marker="o")
plt.plot(x,lr.predict(x),color='red')

plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()
